# %%
import sys
import torch
import gym
import numpy as np
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.autograd import Variable
import matplotlib.pyplot as plt
import pandas as pd

# hyperparameters
hidden_size = 256
learning_rate = 3e-4

# Constants
GAMMA = 0.99
num_steps = 300
max_episodes = 1000

# %%
class ActorCritic(nn.Module):
    def __init__(self, num_inputs, num_actions, hidden_size, learning_rate=3e-4):
        super(ActorCritic, self).__init__()

        self.num_actions = num_actions
        self.critic_linear1 = nn.Linear(num_inputs, hidden_size)
        self.critic_linear2 = nn.Linear(hidden_size, 1)

        self.actor_linear1 = nn.Linear(num_inputs, hidden_size)
        self.actor_linear2 = nn.Linear(hidden_size, num_actions)

    def forward(self, state):
        state = Variable(torch.from_numpy(state).float().unsqueeze(0))
        value = F.relu(self.critic_linear1(state))
        value = self.critic_linear2(value)

        policy_dist = F.relu(self.actor_linear1(state))
        policy_dist = F.softmax(self.actor_linear2(policy_dist), dim=1)

        return value, policy_dist

# %%
def a2c(env):
    num_inputs = env.observation_space.shape[0]
    num_outputs = env.action_space.n

    actor_critic = ActorCritic(num_inputs, num_outputs, hidden_size)
    ac_optimizer = optim.Adam(actor_critic.parameters(), lr=learning_rate)

    all_lengths = []
    average_lengths = []
    all_rewards = []
    entropy_term = 0

    for episode in range(max_episodes):
        log_probs = []
        values = []
        rewards = []

        state = env.reset()
        for steps in range(num_steps):
            value, policy_dist = actor_critic.forward(state)
            value = value.detach().numpy()[0,0]
            dist = policy_dist.detach().numpy()

            action = np.random.choice(num_outputs, p=np.squeeze(dist))
            log_prob = torch.log(policy_dist.squeeze(0)[action])
            entropy = -np.sum(np.mean(dist) * np.log(dist))
            new_state, reward, done, _ = env.step(action)

            rewards.append(reward)
            values.append(value)
            log_probs.append(log_prob)
            entropy_term += entropy
            state = new_state

            if done or steps == num_steps-1:
                Qval, _ = actor_critic.forward(new_state)
                Qval = Qval.detach().numpy()[0,0]
                all_rewards.append(np.sum(rewards))
                all_lengths.append(steps)
                average_lengths.append(np.mean(all_lengths[-10:]))
                if episode % 10 == 0:
                    sys.stdout.write("episode: {}, reward: {}, total length: {}, average length: {} \n".format(episode, np.sum(rewards), steps, average_lengths[-1]))
                break

        # compute Q values
        Qvals = np.zeros_like(values)
        for t in reversed(range(len(rewards))):
            Qval = rewards[t] + GAMMA * Qval
            Qvals[t] = Qval

        #update actor critic
        values = torch.FloatTensor(values)
        Qvals = torch.FloatTensor(Qvals)
        log_probs = torch.stack(log_probs)

        advantage = Qvals - values
        actor_loss = (-log_probs * advantage).mean()
        critic_loss = 0.5 * advantage.pow(2).mean()
        ac_loss = actor_loss + critic_loss + 0.001 * entropy_term

        ac_optimizer.zero_grad()
        ac_loss.backward()
        ac_optimizer.step()



    # Plot results
    smoothed_rewards = pd.Series.rolling(pd.Series(all_rewards), 10).mean()
    smoothed_rewards = [elem for elem in smoothed_rewards]
    plt.plot(all_rewards)
    plt.plot(smoothed_rewards)
    plt.plot()
    plt.xlabel('Episode')
    plt.ylabel('Reward')
    plt.show()

    plt.plot(all_lengths)
    plt.plot(average_lengths)
    plt.xlabel('Episode')
    plt.ylabel('Episode length')
    plt.show()

# %%
if __name__ == "__main__":
    env = gym.make("CartPole-v0")
    a2c(env)
# Out:
# episode: 0, reward: 24.0, total length: 23, average length: 23.0
# episode: 10, reward: 24.0, total length: 23, average length: 20.0
# episode: 20, reward: 18.0, total length: 17, average length: 26.7
# episode: 30, reward: 20.0, total length: 19, average length: 24.6
# episode: 40, reward: 29.0, total length: 28, average length: 22.7
# episode: 50, reward: 31.0, total length: 30, average length: 30.8
# episode: 60, reward: 18.0, total length: 17, average length: 23.4
# episode: 70, reward: 31.0, total length: 30, average length: 35.6
# episode: 80, reward: 53.0, total length: 52, average length: 26.7
# episode: 90, reward: 15.0, total length: 14, average length: 24.6
# episode: 100, reward: 50.0, total length: 49, average length: 34.4
# episode: 110, reward: 80.0, total length: 79, average length: 32.8
# episode: 120, reward: 15.0, total length: 14, average length: 23.8
# episode: 130, reward: 32.0, total length: 31, average length: 49.6
# episode: 140, reward: 23.0, total length: 22, average length: 23.8
# episode: 150, reward: 25.0, total length: 24, average length: 27.1
# episode: 160, reward: 31.0, total length: 30, average length: 31.9
# episode: 170, reward: 10.0, total length: 9, average length: 26.0
# episode: 180, reward: 43.0, total length: 42, average length: 34.9
# episode: 190, reward: 20.0, total length: 19, average length: 30.5
# episode: 200, reward: 31.0, total length: 30, average length: 25.6
# episode: 210, reward: 14.0, total length: 13, average length: 34.5
# episode: 220, reward: 53.0, total length: 52, average length: 39.8
# episode: 230, reward: 17.0, total length: 16, average length: 39.9
# episode: 240, reward: 33.0, total length: 32, average length: 40.2
# episode: 250, reward: 23.0, total length: 22, average length: 36.2
# episode: 260, reward: 43.0, total length: 42, average length: 35.2
# episode: 270, reward: 55.0, total length: 54, average length: 36.4
# episode: 280, reward: 16.0, total length: 15, average length: 42.3
# episode: 290, reward: 29.0, total length: 28, average length: 24.1
# episode: 300, reward: 17.0, total length: 16, average length: 35.0
# episode: 310, reward: 25.0, total length: 24, average length: 33.3
# episode: 320, reward: 38.0, total length: 37, average length: 43.1
# episode: 330, reward: 11.0, total length: 10, average length: 39.7
# episode: 340, reward: 63.0, total length: 62, average length: 50.5
# episode: 350, reward: 51.0, total length: 50, average length: 45.8
# episode: 360, reward: 104.0, total length: 103, average length: 48.0
# episode: 370, reward: 82.0, total length: 81, average length: 38.7
# episode: 380, reward: 25.0, total length: 24, average length: 39.5
# episode: 390, reward: 49.0, total length: 48, average length: 38.3
# episode: 400, reward: 161.0, total length: 160, average length: 61.9
# episode: 410, reward: 129.0, total length: 128, average length: 47.5
# episode: 420, reward: 39.0, total length: 38, average length: 59.8
# episode: 430, reward: 27.0, total length: 26, average length: 42.0
# episode: 440, reward: 29.0, total length: 28, average length: 35.7
# episode: 450, reward: 35.0, total length: 34, average length: 34.5
# episode: 460, reward: 20.0, total length: 19, average length: 52.3
# episode: 470, reward: 35.0, total length: 34, average length: 43.8
# episode: 480, reward: 39.0, total length: 38, average length: 45.4
# episode: 490, reward: 20.0, total length: 19, average length: 42.1
# episode: 500, reward: 15.0, total length: 14, average length: 40.9
# episode: 510, reward: 64.0, total length: 63, average length: 55.1
# episode: 520, reward: 15.0, total length: 14, average length: 52.3
# episode: 530, reward: 70.0, total length: 69, average length: 48.7
# episode: 540, reward: 22.0, total length: 21, average length: 70.9
# episode: 550, reward: 51.0, total length: 50, average length: 67.9
# episode: 560, reward: 35.0, total length: 34, average length: 44.8
# episode: 570, reward: 82.0, total length: 81, average length: 50.7
# episode: 580, reward: 35.0, total length: 34, average length: 71.9
# episode: 590, reward: 19.0, total length: 18, average length: 48.5
# episode: 600, reward: 140.0, total length: 139, average length: 80.4
# episode: 610, reward: 41.0, total length: 40, average length: 52.1
# episode: 620, reward: 51.0, total length: 50, average length: 61.4
# episode: 630, reward: 82.0, total length: 81, average length: 78.2
# episode: 640, reward: 27.0, total length: 26, average length: 70.5
# episode: 650, reward: 116.0, total length: 115, average length: 54.2
# episode: 660, reward: 97.0, total length: 96, average length: 58.0
# episode: 670, reward: 96.0, total length: 95, average length: 81.4
# episode: 680, reward: 38.0, total length: 37, average length: 66.2
# episode: 690, reward: 102.0, total length: 101, average length: 82.8
# episode: 700, reward: 26.0, total length: 25, average length: 72.3
# episode: 710, reward: 113.0, total length: 112, average length: 75.2
# episode: 720, reward: 108.0, total length: 107, average length: 89.3
# episode: 730, reward: 79.0, total length: 78, average length: 86.1
# episode: 740, reward: 44.0, total length: 43, average length: 73.6
# episode: 750, reward: 62.0, total length: 61, average length: 68.1
# episode: 760, reward: 68.0, total length: 67, average length: 69.6
# episode: 770, reward: 155.0, total length: 154, average length: 76.3
# episode: 780, reward: 117.0, total length: 116, average length: 71.4
# episode: 790, reward: 47.0, total length: 46, average length: 77.4
# episode: 800, reward: 126.0, total length: 125, average length: 90.5
# episode: 810, reward: 101.0, total length: 100, average length: 105.5
# episode: 820, reward: 72.0, total length: 71, average length: 68.5
# episode: 830, reward: 69.0, total length: 68, average length: 93.4
# episode: 840, reward: 82.0, total length: 81, average length: 101.4
# episode: 850, reward: 124.0, total length: 123, average length: 82.4
# episode: 860, reward: 39.0, total length: 38, average length: 110.9
# episode: 870, reward: 75.0, total length: 74, average length: 113.5
# episode: 880, reward: 124.0, total length: 123, average length: 96.7
# episode: 890, reward: 81.0, total length: 80, average length: 103.3
# episode: 900, reward: 17.0, total length: 16, average length: 98.8
# episode: 910, reward: 82.0, total length: 81, average length: 104.4
# episode: 920, reward: 33.0, total length: 32, average length: 106.0
# episode: 930, reward: 34.0, total length: 33, average length: 101.5
# episode: 940, reward: 71.0, total length: 70, average length: 78.4
# episode: 950, reward: 175.0, total length: 174, average length: 128.1
# episode: 960, reward: 131.0, total length: 130, average length: 115.0
# episode: 970, reward: 180.0, total length: 179, average length: 104.5
# episode: 980, reward: 200.0, total length: 199, average length: 141.4
# episode: 990, reward: 200.0, total length: 199, average length: 139.7
